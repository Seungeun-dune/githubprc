# %% [markdown]
# <a href="https://colab.research.google.com/github/Seungeun-dune/githubprc/blob/main/githubpractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
a = np.array([[1,2],[2,3]])

# %%
print(a)
# Out:
# [[1 2]
#  [2 3]]

# %%
# !git config -- global user.email "duneag2@gmail.com"
# !git config -- global user.name "Seungeun-dune"
# Out:
# fatal: not in a git directory
# fatal: not in a git directory
